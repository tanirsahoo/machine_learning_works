# %%
import pandas as pd

# %%
employees = {
    "Name": ["Tanir", "Rahul", "Ananya", "Priya"],
    "Age": [24, 27, 22, 25],
    "Department": ["AI", "Backend", "HR", "AI"],
    "Salary": [70000, 85000, 50000, 72000]
}

# %%
df = pd.DataFrame(employees)

# %%
df
# Out:
#      Name  Age Department  Salary
# 0   Tanir   24         AI   70000
# 1   Rahul   27    Backend   85000
# 2  Ananya   22         HR   50000
# 3   Priya   25         AI   72000

# %%
df.head()
# Out:
#      Name  Age Department  Salary
# 0   Tanir   24         AI   70000
# 1   Rahul   27    Backend   85000
# 2  Ananya   22         HR   50000
# 3   Priya   25         AI   72000

# %%
df.tail()
# Out:
#      Name  Age Department  Salary
# 0   Tanir   24         AI   70000
# 1   Rahul   27    Backend   85000
# 2  Ananya   22         HR   50000
# 3   Priya   25         AI   72000

# %%
df.shape
# Out:
# (4, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='str')

# %%
df["Name"]
# Out:
# 0     Tanir
# 1     Rahul
# 2    Ananya
# 3     Priya
# Name: Name, dtype: str

# %%
df[['Name' , 'Age']]
# Out:
#      Name  Age
# 0   Tanir   24
# 1   Rahul   27
# 2  Ananya   22
# 3   Priya   25

# %%
df[df["Department"] == 'AI']
# Out:
#     Name  Age Department  Salary
# 0  Tanir   24         AI   70000
# 3  Priya   25         AI   72000

# %%
df["Bonus"] = df["Salary"] * 0.10

# %%
df
# Out:
#      Name  Age Department  Salary   Bonus
# 0   Tanir   24         AI   70000  7000.0
# 1   Rahul   27    Backend   85000  8500.0
# 2  Ananya   22         HR   50000  5000.0
# 3   Priya   25         AI   72000  7200.0

# %%
df.sort_values("Age")
# Out:
#      Name  Age Department  Salary   Bonus
# 2  Ananya   22         HR   50000  5000.0
# 0   Tanir   24         AI   70000  7000.0
# 3   Priya   25         AI   72000  7200.0
# 1   Rahul   27    Backend   85000  8500.0

# %%
df = df.sort_values("Salary")

# %%
df
# Out:
#      Name  Age Department  Salary   Bonus
# 2  Ananya   22         HR   50000  5000.0
# 0   Tanir   24         AI   70000  7000.0
# 3   Priya   25         AI   72000  7200.0
# 1   Rahul   27    Backend   85000  8500.0

# %%
df.sort_values("Salary" , ascending=False)
# Out:
#      Name  Age Department  Salary   Bonus
# 1   Rahul   27    Backend   85000  8500.0
# 3   Priya   25         AI   72000  7200.0
# 0   Tanir   24         AI   70000  7000.0
# 2  Ananya   22         HR   50000  5000.0

# %%
dirty_data = {
    "Name": ["Tanir", "Rahul", None, "Priya"],
    "Age": [24, None, 22, 25],
    "Salary": [70000, 85000, None, 72000]
}

# %%
dirty_df = pd.DataFrame(dirty_data)

# %%
dirty_df
# Out:
#     Name   Age   Salary
# 0  Tanir  24.0  70000.0
# 1  Rahul   NaN  85000.0
# 2    NaN  22.0      NaN
# 3  Priya  25.0  72000.0

# %%
dirty_df.isnull()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False

# %%
dirty_df.isnull().sum()
# Out:
# Name      1
# Age       1
# Salary    1
# dtype: int64

# %%
dirty_df.dropna()
# Out:
#     Name   Age   Salary
# 0  Tanir  24.0  70000.0
# 3  Priya  25.0  72000.0

# %%
dirty_df["Age"].fillna(dirty_df["Age"].mean())
# Out:
# 0    24.000000
# 1    23.666667
# 2    22.000000
# 3    25.000000
# Name: Age, dtype: float64

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# AI         71000.0
# Backend    85000.0
# HR         50000.0
# Name: Salary, dtype: float64
